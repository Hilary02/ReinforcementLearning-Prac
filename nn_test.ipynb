# %% [markdown]
# https://indico2.riken.jp/event/2492/attachments/4803/5587/Tanaka_Lecture.pdf
# に沿ってkerasというかDLの流れ全体を学んでいきたい

# %%
import gym
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation
import numpy as np

# %%
Test_NN = Sequential()
print(Test_NN)

Test_NN.add(Dense(4,input_dim=3))
Test_NN.add(Activation('sigmoid'))
Test_NN.add(Dense(3))
Test_NN.add(Activation('softmax'))
print(Test_NN.summary())
Test_NN.compile(optimizer='adam',loss='categorical_crossentropy')
# Out:
# ...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_15 (Dense)             (None, 4)                 16
# _________________________________________________________________
# activation_15 (Activation)   (None, 4)                 0
# _________________________________________________________________
# dense_16 (Dense)             (None, 3)                 15
# _________________________________________________________________
# activation_16 (Activation)   (None, 3)                 0
# ...
# Total params: 31
# Trainable params: 31
# Non-trainable params: 0
# _________________________________________________________________
# None
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_15 (Dense)             (None, 4)                 16
# _________________________________________________________________
# ...

# %%
x = np.array([[0,1,2],[1,3,1],[3,1,-1],[5,2,0],[0,8,0]])
y = np.array([[1,0,0],[1,0,0],[0,1,0],[0,0,1],[0,1,0]])

# %%
Test_NN.fit(x,y,epochs=3)
# Out:
# Epoch 1/3
# 5/5 [==============================] - 0s 368us/step - loss: 1.2911
# Epoch 2/3
# 5/5 [==============================] - 0s 267us/step - loss: 1.2894
# Epoch 3/3
# 5/5 [==============================] - 0s 241us/step - loss: 1.2876

# %%
Test_NN.fit(x,y,epochs=500)
# Out:
# Epoch 1/500
# 5/5 [==============================] - 0s 316us/step - loss: 1.2857
# Epoch 2/500
# 5/5 [==============================] - 0s 263us/step - loss: 1.2839
# Epoch 3/500
# 5/5 [==============================] - 0s 256us/step - loss: 1.2821
# Epoch 4/500
# 5/5 [==============================] - 0s 343us/step - loss: 1.2803
# Epoch 5/500
# 5/5 [==============================] - 0s 236us/step - loss: 1.2785
# Epoch 6/500
# 5/5 [==============================] - 0s 207us/step - loss: 1.2767
# Epoch 7/500
# 5/5 [==============================] - 0s 246us/step - loss: 1.2749
# Epoch 8/500
# 5/5 [==============================] - 0s 208us/step - loss: 1.2731
# Epoch 9/500
# 5/5 [==============================] - 0s 239us/step - loss: 1.2713
# Epoch 10/500
# 5/5 [==============================] - 0s 224us/step - loss: 1.2695
# Epoch 11/500
# 5/5 [==============================] - 0s 198us/step - loss: 1.2677
# Epoch 12/500
# ...

# %%
Test_NN.predict(x),y
# Out:
# (array([[0.6963771 , 0.17773578, 0.12588713],
#         [0.45760798, 0.3665254 , 0.17586665],
#         [0.34616846, 0.4516    , 0.20223159],
#         [0.30297542, 0.45543456, 0.24159007],
#         [0.25795403, 0.5984207 , 0.14362526]], dtype=float32),
#  array([[1, 0, 0],
#         [1, 0, 0],
#         [0, 1, 0],
#         [0, 0, 1],
#         [0, 1, 0]]))

# %%
# 手書き数字を学ばせる
from keras.datasets import mnist
